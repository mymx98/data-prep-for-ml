# %%
import matplotlib.pyplot as plt
import pandas as pd
from pandas.plotting import parallel_coordinates
import seaborn as sns

# %% [markdown]
# ## Plots Inside cells

# %% [markdown]
# #### `figure, axes = plt.subplots()`
#
# The code will create a figure with a single cell called `axes`
# where a plot will be drawn by `axes.plot()`
#
# **Note:** Sometimes you see code like `plt.plot()`;
#     this will directly draw a plot without creating a cell.

# %% [markdown]
# ## Line plots
#
# ### matplotlib: plot()

# %%
aus_temp = pd.read_csv('max_temp.csv')
aus_temp.head(10)
# Out:
#   city/month   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct  \
# 0  Melbourne  41.2  35.5  37.4  29.3  23.9  16.8  18.2  25.7  22.3  33.5
# 1   Brisbane  31.3  40.2  37.9  29.0  30.0  26.7  26.7  28.8  31.2  34.1
# 2     Darwin  34.0  34.0  33.2  34.5  34.8  33.9  32.0  34.3  36.1  35.4
# 3      Perth  41.9  41.5  42.4  36.0  26.9  24.5  23.8  24.3  27.6  30.7
# 4   Adelaide  42.1  38.1  39.7  33.5  26.3  16.5  21.4  30.4  30.2  34.9
# 5   Canberra  35.8  29.6  35.1  26.5  22.4  15.3  15.7  21.9  22.1  30.8
# 6     Hobart  35.5  34.1  30.7  26.0  20.9  15.1  17.5  21.7  20.9  24.2
# 7     Sydney  30.6  29.0  35.1  27.1  28.6  20.7  23.4  27.7  28.6  34.8
#
#     Nov   Dec
# 0  36.9  41.1
# 1  31.1  31.2
# 2  37.0  35.5
# 3  39.8  44.2
# 4  37.1  42.2
# 5  33.4  35.0
# 6  30.1  33.4
# 7  26.4  30.2

# %%
# This function renders the figure in a notebook
# %matplotlib inline
# Create figure with a single plot
fig, ax = plt.subplots() 

# Plot a line avg max temperture for each city
for i, row in aus_temp.iterrows():
    ax.plot(row[1:])
    
ax.legend(aus_temp['city/month'])

# %% [markdown]
# ### pandas: line()

# %%
# transpose the dataframe
aus_temp_t = aus_temp.iloc[:, 1:].T
aus_temp_t.columns = aus_temp['city/month']
aus_temp_t
# Out:
# city/month  Melbourne  Brisbane  Darwin  Perth  Adelaide  Canberra  Hobart  \
# Jan              41.2      31.3    34.0   41.9      42.1      35.8    35.5
# Feb              35.5      40.2    34.0   41.5      38.1      29.6    34.1
# Mar              37.4      37.9    33.2   42.4      39.7      35.1    30.7
# Apr              29.3      29.0    34.5   36.0      33.5      26.5    26.0
# May              23.9      30.0    34.8   26.9      26.3      22.4    20.9
# Jun              16.8      26.7    33.9   24.5      16.5      15.3    15.1
# Jul              18.2      26.7    32.0   23.8      21.4      15.7    17.5
# Aug              25.7      28.8    34.3   24.3      30.4      21.9    21.7
# Sep              22.3      31.2    36.1   27.6      30.2      22.1    20.9
# Oct              33.5      34.1    35.4   30.7      34.9      30.8    24.2
# Nov              36.9      31.1    37.0   39.8      37.1      33.4    30.1
# ...

# %%
lines = aus_temp_t.plot.line()

# %%
# create a DataFrame from a csv file of CO2 emissions between 1990 and 2016
car = pd.read_csv('mpg.csv', encoding = 'ISO-8859-1')
#car.columns
car.head(10)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0         130    3504          12.0
# 1  15.0          8         350.0         165    3693          11.5
# 2  18.0          8         318.0         150    3436          11.0
# 3  16.0          8         304.0         150    3433          12.0
# 4  17.0          8         302.0         140    3449          10.5
# 5  15.0          8         429.0         198    4341          10.0
# 6  14.0          8         454.0         220    4354           9.0
# 7  14.0          8         440.0         215    4312           8.5
# 8  14.0          8         455.0         225    4425          10.0
# 9  15.0          8         390.0         190    3850           8.5
#
#    model_year  origin                       name
# 0          70       1  chevrolet chevelle malibu
# 1          70       1          buick skylark 320
# 2          70       1         plymouth satellite
# ...

# %% [markdown]
# ## Boxplots
#
# ### matplotlib: boxplot()

# %%
horsepower = car['horsepower']

# create a figure with a single plot.
fig, ax = plt.subplots()

ax.boxplot(horsepower)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x29c2eaf7a00>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x29c2eb05100>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x29c2eaf76a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x29c2eb057c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x29c2eb05ac0>],
#  'means': []}

# %% [markdown]
# ### pandas: boxplot()

# %%
car.boxplot('horsepower')
# Out:
# <AxesSubplot:>

# %%
car.boxplot(['horsepower', 'acceleration'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Histograms
#
# ### matplotlib: hist()

# %%
# create a figure with a single plot.
fig, ax = plt.subplots()

ax.hist(car['horsepower'])
# Out:
# (array([ 27.,  95., 120.,  44.,  19.,  47.,  13.,  14.,   5.,   8.]),
#  array([ 46. ,  64.4,  82.8, 101.2, 119.6, 138. , 156.4, 174.8, 193.2,
#         211.6, 230. ]),
#  <BarContainer object of 10 artists>)

# %%
bin_sizes = [3, 10, 30]

fig, axs = plt.subplots(3)
fig.suptitle('Histograms with different bin sizes')

for i, size in enumerate(bin_sizes):
    axs[i].hist(car['horsepower'], bins=size)

# %% [markdown]
# ### pandas: hist()

# %%
car.hist('horsepower', bins=10)
# Out:
# array([[<AxesSubplot:title={'center':'horsepower'}>]], dtype=object)

# %% [markdown]
# ## Bar charts
#
# ### matplotlib: bar()

# %%
avg_by_origin = car.groupby('origin').mean()
avg_by_origin
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# origin
# 1       20.033469   6.277551    247.512245  119.048980  3372.489796
# 2       27.602941   4.161765    109.632353   80.558824  2433.470588
# 3       30.450633   4.101266    102.708861   79.835443  2221.227848
#
#         acceleration  model_year
# origin
# 1          14.990204   75.591837
# 2          16.794118   75.676471
# 3          16.172152   77.443038

# %%
# create a figure with a single plot.
fig, ax = plt.subplots()

ax.bar(['orgin ' + str(x) for x in avg_by_origin.index], avg_by_origin['horsepower'])

# customise the x-axis
#plt.xticks(avg_by_origin.index, ['org-' + str(x) for x in avg_by_origin.index])
# Out:
# <BarContainer object of 3 artists>

# %% [markdown]
# ### pandas: bar()

# %%
avg_by_origin.plot.bar(x=None, y='horsepower')
# Out:
# <AxesSubplot:xlabel='origin'>

# %%
avg_by_origin.plot.bar(x=None, y=['horsepower', 'displacement'])
# Out:
# <AxesSubplot:xlabel='origin'>

# %% [markdown]
# ## Scatter plots
#
# ### matplotlib: scatter()

# %%
# we have 3 subsets of cars, from 3 different origin. We are interested in exploring the relationships between horsepower and acceleration.
car1 = car.loc[car['origin'] == 1, ['horsepower', 'acceleration']]
car2 = car.loc[car['origin'] == 2, ['horsepower', 'acceleration']]
car3 = car.loc[car['origin'] == 3, ['horsepower', 'acceleration']]

car1.shape, car2.shape, car3.shape
# Out:
# ((245, 2), (68, 2), (79, 2))

# %%
# create a figure with a single plot.
fig, ax = plt.subplots()

ax.scatter(car1['horsepower'],car1['acceleration'],color='purple')
ax.scatter(car2['horsepower'],car2['acceleration'],color='teal')
ax.scatter(car3['horsepower'],car3['acceleration'],color='yellow')

# %% [markdown]
# ### pandas: scatter()

# %%
car.plot.scatter(x='horsepower', y='acceleration', c='origin', colormap='viridis')
# Out:
# <AxesSubplot:xlabel='horsepower', ylabel='acceleration'>

# %% [markdown]
# ## Parallel co-ordinate plots

# %%
# prepare the data
columns = car.columns.tolist()
# select the numeric features
features = car[columns[:6]].copy()
# process class labels
features['class'] = ['origin ' + str(x) for x in car['origin']]

# %%
parallel_coordinates(features, class_column = 'class', color = ['blue', 'green', 'orange'])
# Out:
# <AxesSubplot:>

# %%
# normalise the data
columns = car.columns.tolist()
features = car[columns[:6]].copy()

features_norm = (features - features.min())/(features.max() - features.min())
# features_sd = (features - features.mean())/features.std()
features_norm['class'] = ['origin ' + str(x) for x in car['origin']]
features_norm
# Out:
#           mpg  cylinders  displacement  horsepower    weight  acceleration  \
# 0    0.239362        1.0      0.617571    0.456522  0.536150      0.238095
# 1    0.159574        1.0      0.728682    0.646739  0.589736      0.208333
# 2    0.239362        1.0      0.645995    0.565217  0.516870      0.178571
# 3    0.186170        1.0      0.609819    0.565217  0.516019      0.238095
# 4    0.212766        1.0      0.604651    0.510870  0.520556      0.148810
# ..        ...        ...           ...         ...       ...           ...
# 387  0.478723        0.2      0.186047    0.217391  0.333711      0.452381
# 388  0.930851        0.2      0.074935    0.032609  0.146583      0.988095
# 389  0.611702        0.2      0.173127    0.206522  0.193365      0.214286
# 390  0.505319        0.2      0.134367    0.179348  0.286929      0.630952
# 391  0.585106        0.2      0.131783    0.195652  0.313864      0.678571
#
#         class
# 0    origin 1
# 1    origin 1
# 2    origin 1
# ...

# %%
parallel_coordinates(features_norm, class_column = 'class', color = ['blue', 'green', 'orange'])
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Heatmaps
#
# ### matplotlib: matshow()

# %%
# create a figure with a single plot.
fig, ax = plt.subplots()
ax.matshow(features, aspect='auto')

# %% [markdown]
# ### seaborn: heatmap()

# %%
features['class'] = ['origin ' + str(x) for x in car['origin']]
features = features.set_index('class').sort_index()
fig, ax = plt.subplots()
sns.heatmap(features, cmap='viridis', xticklabels=True, ax=ax)
ax.tick_params(axis='x', labelrotation=30, direction='out')

# %%
features_norm = (features - features.min())/(features.max() - features.min())
#features_sd = (features - features.mean())/features.std()

features_norm['class'] = ['origin ' + str(x) for x in car['origin']]
features_norm = features_norm.set_index('class').sort_index()

fig, ax = plt.subplots()
sns.heatmap(features_norm, cmap='viridis', xticklabels=True, ax=ax)
# Out:
# <AxesSubplot:ylabel='class'>
